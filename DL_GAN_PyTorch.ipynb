# %% [markdown]
# <a href="https://colab.research.google.com/github/EDPS-7532/ups7532/blob/main/DL_GAN_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import torch.nn as nn

from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.utils import save_image

# %%
latent_dim = 100


# 생성자(Generator) 클래스 정의
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        # 하나의 블록(block) 정의
        def block(input_dim, output_dim, normalize=True):
            layers = [nn.Linear(input_dim, output_dim)]
            if normalize:
                # 배치 정규화(batch normalization) 수행(차원 동일)
                layers.append(nn.BatchNorm1d(output_dim, 0.8))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        # 생성자 모델은 연속적인 여러 개의 블록을 가짐
        self.model = nn.Sequential(
            *block(latent_dim, 128, normalize=False),
            *block(128, 256),
            *block(256, 512),
            *block(512, 1024),
            nn.Linear(1024, 1 * 28 * 28),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        img = img.view(img.size(0), 1, 28, 28)
        return img

# %%
# 판별자(Discriminator) 클래스 정의
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(1 * 28 * 28, 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
            nn.Sigmoid(),
        )

    # 이미지에 대한 판별 결과를 반환
    def forward(self, img):
        flattened = img.view(img.size(0), -1)
        output = self.model(flattened)

        return output

# %%
transforms_train = transforms.Compose([
    transforms.Resize(28),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

train_dataset = datasets.MNIST(root="./dataset", train=True, download=True, transform=transforms_train)
dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)

# %%
# 생성자(generator)와 판별자(discriminator) 초기화
generator = Generator()
discriminator = Discriminator()

generator.cuda()
discriminator.cuda()

# 손실 함수(loss function)
adversarial_loss = nn.BCELoss()
adversarial_loss.cuda()

# 학습률(learning rate) 설정
lr = 0.0002

# 생성자와 판별자를 위한 최적화 함수
optimizer_G = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))

# %%
import time

n_epochs = 200 # 학습의 횟수(epoch) 설정
sample_interval = 2000 # 몇 번의 배치(batch)마다 결과를 출력할 것인지 설정
start_time = time.time()

for epoch in range(n_epochs):
    for i, (imgs, _) in enumerate(dataloader):

        # 진짜(real) 이미지와 가짜(fake) 이미지에 대한 정답 레이블 생성
        real = torch.cuda.FloatTensor(imgs.size(0), 1).fill_(1.0) # 진짜(real): 1
        fake = torch.cuda.FloatTensor(imgs.size(0), 1).fill_(0.0) # 가짜(fake): 0

        real_imgs = imgs.cuda()

        """ 생성자(generator)를 학습합니다. """
        optimizer_G.zero_grad()

        # 랜덤 노이즈(noise) 샘플링
        z = torch.normal(mean=0, std=1, size=(imgs.shape[0], latent_dim)).cuda()

        # 이미지 생성
        generated_imgs = generator(z)

        # 생성자(generator)의 손실(loss) 값 계산
        g_loss = adversarial_loss(discriminator(generated_imgs), real)

        # 생성자(generator) 업데이트
        g_loss.backward()
        optimizer_G.step()

        """ 판별자(discriminator)를 학습합니다. """
        optimizer_D.zero_grad()

        # 판별자(discriminator)의 손실(loss) 값 계산
        real_loss = adversarial_loss(discriminator(real_imgs), real)
        fake_loss = adversarial_loss(discriminator(generated_imgs.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2

        # 판별자(discriminator) 업데이트
        d_loss.backward()
        optimizer_D.step()

        done = epoch * len(dataloader) + i
        if done % sample_interval == 0:
            # 생성된 이미지 중에서 25개만 선택하여 5 X 5 격자 이미지에 출력
            save_image(generated_imgs.data[:25], f"{done}.png", nrow=5, normalize=True)

    # 하나의 epoch이 끝날 때마다 로그(log) 출력
    print(f"[Epoch {epoch}/{n_epochs}] [D loss: {d_loss.item():.6f}] [G loss: {g_loss.item():.6f}] [Elapsed time: {time.time() - start_time:.2f}s]")
# Out:
# [Epoch 0/200] [D loss: 0.406222] [G loss: 1.130938] [Elapsed time: 9.10s]
# [Epoch 1/200] [D loss: 0.287077] [G loss: 3.231763] [Elapsed time: 18.12s]
# [Epoch 2/200] [D loss: 0.212003] [G loss: 1.488136] [Elapsed time: 27.18s]
# [Epoch 3/200] [D loss: 0.848704] [G loss: 0.228004] [Elapsed time: 36.17s]
# [Epoch 4/200] [D loss: 0.240223] [G loss: 1.403125] [Elapsed time: 45.17s]
# [Epoch 5/200] [D loss: 0.136496] [G loss: 3.143699] [Elapsed time: 54.12s]
# [Epoch 6/200] [D loss: 0.502932] [G loss: 1.355970] [Elapsed time: 63.17s]
# [Epoch 7/200] [D loss: 0.584242] [G loss: 5.565967] [Elapsed time: 72.13s]
# [Epoch 8/200] [D loss: 0.215574] [G loss: 1.623347] [Elapsed time: 81.10s]
# [Epoch 9/200] [D loss: 0.206234] [G loss: 2.199450] [Elapsed time: 90.06s]
# [Epoch 10/200] [D loss: 0.285986] [G loss: 3.531826] [Elapsed time: 99.06s]
# [Epoch 11/200] [D loss: 0.194425] [G loss: 2.899347] [Elapsed time: 108.04s]
# [Epoch 12/200] [D loss: 0.135348] [G loss: 2.908133] [Elapsed time: 117.03s]
# [Epoch 13/200] [D loss: 0.118664] [G loss: 2.781374] [Elapsed time: 125.97s]
# [Epoch 14/200] [D loss: 0.311737] [G loss: 2.790472] [Elapsed time: 135.00s]
# [Epoch 15/200] [D loss: 0.325536] [G loss: 1.025454] [Elapsed time: 143.99s]
# [Epoch 16/200] [D loss: 0.149625] [G loss: 1.604144] [Elapsed time: 152.95s]
# [Epoch 17/200] [D loss: 0.150329] [G loss: 3.440610] [Elapsed time: 161.99s]
# [Epoch 18/200] [D loss: 0.166583] [G loss: 2.311494] [Elapsed time: 171.06s]
# [Epoch 19/200] [D loss: 0.361990] [G loss: 1.162753] [Elapsed time: 179.97s]
# [Epoch 20/200] [D loss: 0.142707] [G loss: 2.133840] [Elapsed time: 188.90s]
# [Epoch 21/200] [D loss: 0.225970] [G loss: 3.602501] [Elapsed time: 197.82s]
# [Epoch 22/200] [D loss: 0.120949] [G loss: 2.140480] [Elapsed time: 206.80s]
# [Epoch 23/200] [D loss: 0.189653] [G loss: 3.883459] [Elapsed time: 215.82s]
# [Epoch 24/200] [D loss: 0.120769] [G loss: 2.416262] [Elapsed time: 224.82s]
# [Epoch 25/200] [D loss: 0.140844] [G loss: 2.339986] [Elapsed time: 233.81s]
# [Epoch 26/200] [D loss: 0.230947] [G loss: 4.699417] [Elapsed time: 242.79s]
# [Epoch 27/200] [D loss: 0.151537] [G loss: 2.381473] [Elapsed time: 251.94s]
# [Epoch 28/200] [D loss: 0.343170] [G loss: 3.641756] [Elapsed time: 260.93s]
# [Epoch 29/200] [D loss: 0.813483] [G loss: 7.301107] [Elapsed time: 270.01s]
# [Epoch 30/200] [D loss: 0.509146] [G loss: 5.870904] [Elapsed time: 278.97s]
# [Epoch 31/200] [D loss: 0.242125] [G loss: 3.710071] [Elapsed time: 287.96s]
# [Epoch 32/200] [D loss: 0.142242] [G loss: 2.895641] [Elapsed time: 296.93s]
# [Epoch 33/200] [D loss: 0.149694] [G loss: 3.556999] [Elapsed time: 306.10s]
# [Epoch 34/200] [D loss: 0.218185] [G loss: 4.619326] [Elapsed time: 315.01s]
# [Epoch 35/200] [D loss: 0.202956] [G loss: 2.998361] [Elapsed time: 323.97s]
# [Epoch 36/200] [D loss: 0.237174] [G loss: 1.925231] [Elapsed time: 332.95s]
# [Epoch 37/200] [D loss: 0.341057] [G loss: 6.924837] [Elapsed time: 342.15s]
# [Epoch 38/200] [D loss: 0.130565] [G loss: 3.065319] [Elapsed time: 351.20s]
# [Epoch 39/200] [D loss: 0.205753] [G loss: 2.058334] [Elapsed time: 360.13s]
# [Epoch 40/200] [D loss: 0.192579] [G loss: 2.006089] [Elapsed time: 369.09s]
# [Epoch 41/200] [D loss: 1.078925] [G loss: 10.924128] [Elapsed time: 378.06s]
# [Epoch 42/200] [D loss: 0.226407] [G loss: 3.906356] [Elapsed time: 387.13s]
# [Epoch 43/200] [D loss: 0.101095] [G loss: 2.610994] [Elapsed time: 396.17s]
# [Epoch 44/200] [D loss: 0.096629] [G loss: 2.692326] [Elapsed time: 405.11s]
# [Epoch 45/200] [D loss: 0.102175] [G loss: 3.460198] [Elapsed time: 414.10s]
# [Epoch 46/200] [D loss: 0.133548] [G loss: 3.787328] [Elapsed time: 423.10s]
# [Epoch 47/200] [D loss: 0.154756] [G loss: 3.144420] [Elapsed time: 432.13s]
# [Epoch 48/200] [D loss: 0.188743] [G loss: 2.000806] [Elapsed time: 441.10s]
# [Epoch 49/200] [D loss: 0.139460] [G loss: 3.054965] [Elapsed time: 450.12s]
# [Epoch 50/200] [D loss: 0.164266] [G loss: 2.978198] [Elapsed time: 459.10s]
# [Epoch 51/200] [D loss: 0.212780] [G loss: 3.958958] [Elapsed time: 468.12s]
# [Epoch 52/200] [D loss: 0.151659] [G loss: 2.031742] [Elapsed time: 477.11s]
# [Epoch 53/200] [D loss: 0.092862] [G loss: 3.954967] [Elapsed time: 486.08s]
# [Epoch 54/200] [D loss: 0.186994] [G loss: 3.114144] [Elapsed time: 495.01s]
# [Epoch 55/200] [D loss: 0.035633] [G loss: 3.386829] [Elapsed time: 503.98s]
# [Epoch 56/200] [D loss: 0.203671] [G loss: 6.129077] [Elapsed time: 513.02s]
# [Epoch 57/200] [D loss: 0.116470] [G loss: 2.958368] [Elapsed time: 521.93s]
# [Epoch 58/200] [D loss: 0.075776] [G loss: 3.054631] [Elapsed time: 530.95s]
# [Epoch 59/200] [D loss: 0.214389] [G loss: 3.685403] [Elapsed time: 539.91s]
# [Epoch 60/200] [D loss: 0.118198] [G loss: 2.659914] [Elapsed time: 548.90s]
# [Epoch 61/200] [D loss: 0.067000] [G loss: 2.955818] [Elapsed time: 557.83s]
# [Epoch 62/200] [D loss: 0.209161] [G loss: 6.297198] [Elapsed time: 566.83s]
# [Epoch 63/200] [D loss: 0.161837] [G loss: 1.763120] [Elapsed time: 575.89s]
# [Epoch 64/200] [D loss: 0.183678] [G loss: 5.048336] [Elapsed time: 584.82s]
# [Epoch 65/200] [D loss: 0.059103] [G loss: 3.616070] [Elapsed time: 593.75s]
# [Epoch 66/200] [D loss: 0.132497] [G loss: 2.834167] [Elapsed time: 602.75s]
# [Epoch 67/200] [D loss: 0.123766] [G loss: 3.819382] [Elapsed time: 611.68s]
# [Epoch 68/200] [D loss: 0.220035] [G loss: 2.737763] [Elapsed time: 620.70s]
# [Epoch 69/200] [D loss: 0.149817] [G loss: 3.004415] [Elapsed time: 629.68s]
# [Epoch 70/200] [D loss: 0.193280] [G loss: 2.531468] [Elapsed time: 638.76s]
# [Epoch 71/200] [D loss: 0.167193] [G loss: 3.550983] [Elapsed time: 647.76s]
# [Epoch 72/200] [D loss: 0.119115] [G loss: 3.238023] [Elapsed time: 656.71s]
# [Epoch 73/200] [D loss: 0.120688] [G loss: 3.671776] [Elapsed time: 665.68s]
# [Epoch 74/200] [D loss: 0.136557] [G loss: 3.114079] [Elapsed time: 674.61s]
# [Epoch 75/200] [D loss: 0.067113] [G loss: 2.864468] [Elapsed time: 683.51s]
# [Epoch 76/200] [D loss: 0.674597] [G loss: 8.606652] [Elapsed time: 692.45s]
# [Epoch 77/200] [D loss: 0.151833] [G loss: 7.824594] [Elapsed time: 701.34s]
# [Epoch 78/200] [D loss: 0.163555] [G loss: 3.041659] [Elapsed time: 710.29s]
# [Epoch 79/200] [D loss: 0.126033] [G loss: 3.159737] [Elapsed time: 719.23s]
# [Epoch 80/200] [D loss: 0.071428] [G loss: 2.930036] [Elapsed time: 728.20s]
# [Epoch 81/200] [D loss: 0.107159] [G loss: 3.121852] [Elapsed time: 737.16s]
# [Epoch 82/200] [D loss: 0.130213] [G loss: 3.943322] [Elapsed time: 746.19s]
# [Epoch 83/200] [D loss: 0.195544] [G loss: 2.929517] [Elapsed time: 755.17s]
# [Epoch 84/200] [D loss: 0.195688] [G loss: 1.436544] [Elapsed time: 764.13s]
# [Epoch 85/200] [D loss: 0.089794] [G loss: 3.395618] [Elapsed time: 773.17s]
# [Epoch 86/200] [D loss: 0.214721] [G loss: 3.013560] [Elapsed time: 782.08s]
# [Epoch 87/200] [D loss: 0.050658] [G loss: 3.946441] [Elapsed time: 791.00s]
# [Epoch 88/200] [D loss: 0.149168] [G loss: 2.354592] [Elapsed time: 799.94s]
# [Epoch 89/200] [D loss: 0.088136] [G loss: 2.985102] [Elapsed time: 808.86s]
# [Epoch 90/200] [D loss: 0.133249] [G loss: 3.072035] [Elapsed time: 817.94s]
# [Epoch 91/200] [D loss: 0.118810] [G loss: 2.776129] [Elapsed time: 827.01s]
# [Epoch 92/200] [D loss: 0.118626] [G loss: 3.763636] [Elapsed time: 836.00s]
# [Epoch 93/200] [D loss: 0.130788] [G loss: 4.388827] [Elapsed time: 844.97s]
# [Epoch 94/200] [D loss: 0.090102] [G loss: 2.298830] [Elapsed time: 853.92s]
# [Epoch 95/200] [D loss: 0.095715] [G loss: 3.442890] [Elapsed time: 863.00s]
# [Epoch 96/200] [D loss: 0.072412] [G loss: 3.822507] [Elapsed time: 872.03s]
# [Epoch 97/200] [D loss: 0.311813] [G loss: 0.994279] [Elapsed time: 881.04s]
# [Epoch 98/200] [D loss: 0.123791] [G loss: 3.010912] [Elapsed time: 890.11s]
# [Epoch 99/200] [D loss: 0.099552] [G loss: 3.514603] [Elapsed time: 899.16s]
# [Epoch 100/200] [D loss: 0.052165] [G loss: 4.966192] [Elapsed time: 908.18s]
# [Epoch 101/200] [D loss: 0.029045] [G loss: 3.815404] [Elapsed time: 917.16s]
# [Epoch 102/200] [D loss: 0.100446] [G loss: 4.148098] [Elapsed time: 926.11s]
# [Epoch 103/200] [D loss: 0.077354] [G loss: 2.972735] [Elapsed time: 935.06s]
# [Epoch 104/200] [D loss: 0.392153] [G loss: 3.461760] [Elapsed time: 944.07s]
# [Epoch 105/200] [D loss: 0.229860] [G loss: 1.611208] [Elapsed time: 953.10s]
# [Epoch 106/200] [D loss: 0.113985] [G loss: 3.577182] [Elapsed time: 962.03s]
# [Epoch 107/200] [D loss: 0.103057] [G loss: 2.924897] [Elapsed time: 970.98s]
# [Epoch 108/200] [D loss: 0.139374] [G loss: 2.651625] [Elapsed time: 979.92s]
# [Epoch 109/200] [D loss: 0.100374] [G loss: 3.096936] [Elapsed time: 988.95s]
# [Epoch 110/200] [D loss: 0.214816] [G loss: 3.059048] [Elapsed time: 997.92s]
# [Epoch 111/200] [D loss: 0.116538] [G loss: 5.620406] [Elapsed time: 1006.90s]
# [Epoch 112/200] [D loss: 0.072143] [G loss: 2.994235] [Elapsed time: 1015.84s]
# [Epoch 113/200] [D loss: 0.056068] [G loss: 3.466797] [Elapsed time: 1024.78s]
# [Epoch 114/200] [D loss: 0.241637] [G loss: 2.396758] [Elapsed time: 1033.66s]
# [Epoch 115/200] [D loss: 0.173252] [G loss: 1.951729] [Elapsed time: 1042.58s]
# [Epoch 116/200] [D loss: 0.162000] [G loss: 2.982957] [Elapsed time: 1051.55s]
# [Epoch 117/200] [D loss: 0.093485] [G loss: 4.475681] [Elapsed time: 1060.48s]
# [Epoch 118/200] [D loss: 0.080011] [G loss: 2.491107] [Elapsed time: 1069.45s]
# [Epoch 119/200] [D loss: 0.110582] [G loss: 4.363966] [Elapsed time: 1078.44s]
# [Epoch 120/200] [D loss: 0.144719] [G loss: 6.344326] [Elapsed time: 1087.30s]
# [Epoch 121/200] [D loss: 0.263321] [G loss: 2.651706] [Elapsed time: 1096.28s]
# [Epoch 122/200] [D loss: 0.069728] [G loss: 3.179521] [Elapsed time: 1105.22s]
# [Epoch 123/200] [D loss: 0.194241] [G loss: 3.272100] [Elapsed time: 1114.07s]
# [Epoch 124/200] [D loss: 0.125707] [G loss: 3.188694] [Elapsed time: 1122.94s]
# [Epoch 125/200] [D loss: 0.152698] [G loss: 2.642947] [Elapsed time: 1131.90s]
# [Epoch 126/200] [D loss: 0.102696] [G loss: 2.787664] [Elapsed time: 1140.87s]
# [Epoch 127/200] [D loss: 0.132972] [G loss: 4.068599] [Elapsed time: 1149.81s]
# [Epoch 128/200] [D loss: 0.115640] [G loss: 3.127374] [Elapsed time: 1158.72s]
# [Epoch 129/200] [D loss: 0.206523] [G loss: 4.233291] [Elapsed time: 1167.59s]
# [Epoch 130/200] [D loss: 0.190396] [G loss: 2.089580] [Elapsed time: 1176.56s]
# [Epoch 131/200] [D loss: 0.081976] [G loss: 3.236866] [Elapsed time: 1185.49s]
# [Epoch 132/200] [D loss: 0.083044] [G loss: 3.245000] [Elapsed time: 1194.47s]
# [Epoch 133/200] [D loss: 0.202382] [G loss: 1.588608] [Elapsed time: 1203.38s]
# [Epoch 134/200] [D loss: 0.068589] [G loss: 2.714796] [Elapsed time: 1212.33s]
# [Epoch 135/200] [D loss: 0.117758] [G loss: 3.935218] [Elapsed time: 1221.27s]
# [Epoch 136/200] [D loss: 0.141652] [G loss: 2.781796] [Elapsed time: 1230.24s]
# [Epoch 137/200] [D loss: 0.083050] [G loss: 2.622725] [Elapsed time: 1239.14s]
# [Epoch 138/200] [D loss: 0.162194] [G loss: 1.631407] [Elapsed time: 1248.06s]
# [Epoch 139/200] [D loss: 0.150917] [G loss: 2.398812] [Elapsed time: 1256.98s]
# [Epoch 140/200] [D loss: 0.148902] [G loss: 5.090874] [Elapsed time: 1265.89s]
# [Epoch 141/200] [D loss: 0.154614] [G loss: 3.944770] [Elapsed time: 1274.77s]
# [Epoch 142/200] [D loss: 0.327624] [G loss: 7.027366] [Elapsed time: 1283.73s]
# [Epoch 143/200] [D loss: 0.095009] [G loss: 3.401352] [Elapsed time: 1292.61s]
# [Epoch 144/200] [D loss: 0.112606] [G loss: 3.285228] [Elapsed time: 1301.58s]
# [Epoch 145/200] [D loss: 0.148184] [G loss: 2.569780] [Elapsed time: 1310.56s]
# [Epoch 146/200] [D loss: 0.100771] [G loss: 2.893766] [Elapsed time: 1319.55s]
# [Epoch 147/200] [D loss: 0.184518] [G loss: 2.937334] [Elapsed time: 1328.52s]
# [Epoch 148/200] [D loss: 0.237357] [G loss: 2.898622] [Elapsed time: 1337.50s]
# [Epoch 149/200] [D loss: 0.144888] [G loss: 2.561203] [Elapsed time: 1346.44s]
# [Epoch 150/200] [D loss: 0.081368] [G loss: 3.376605] [Elapsed time: 1355.44s]
# [Epoch 151/200] [D loss: 0.106202] [G loss: 3.355611] [Elapsed time: 1364.39s]
# [Epoch 152/200] [D loss: 0.183215] [G loss: 2.552582] [Elapsed time: 1373.37s]
# [Epoch 153/200] [D loss: 0.204794] [G loss: 1.721584] [Elapsed time: 1382.37s]
# [Epoch 154/200] [D loss: 0.141232] [G loss: 4.555358] [Elapsed time: 1391.36s]
# [Epoch 155/200] [D loss: 0.154503] [G loss: 3.129528] [Elapsed time: 1400.33s]
# [Epoch 156/200] [D loss: 0.139152] [G loss: 3.168722] [Elapsed time: 1409.25s]
# [Epoch 157/200] [D loss: 0.121707] [G loss: 3.625034] [Elapsed time: 1418.23s]
# [Epoch 158/200] [D loss: 0.231590] [G loss: 3.185174] [Elapsed time: 1427.12s]
# [Epoch 159/200] [D loss: 0.125328] [G loss: 2.865999] [Elapsed time: 1436.08s]
# [Epoch 160/200] [D loss: 0.121854] [G loss: 4.053543] [Elapsed time: 1445.01s]
# [Epoch 161/200] [D loss: 0.112817] [G loss: 3.858024] [Elapsed time: 1453.97s]
# [Epoch 162/200] [D loss: 0.118568] [G loss: 2.426702] [Elapsed time: 1462.95s]
# [Epoch 163/200] [D loss: 0.173965] [G loss: 3.362523] [Elapsed time: 1471.91s]
# [Epoch 164/200] [D loss: 0.207425] [G loss: 7.706800] [Elapsed time: 1480.85s]
# [Epoch 165/200] [D loss: 0.054983] [G loss: 4.506919] [Elapsed time: 1489.88s]
# [Epoch 166/200] [D loss: 0.116360] [G loss: 3.263021] [Elapsed time: 1498.83s]
# [Epoch 167/200] [D loss: 0.158592] [G loss: 3.922032] [Elapsed time: 1507.85s]
# [Epoch 168/200] [D loss: 0.142122] [G loss: 2.030925] [Elapsed time: 1516.79s]
# [Epoch 169/200] [D loss: 0.168747] [G loss: 3.552088] [Elapsed time: 1525.77s]
# [Epoch 170/200] [D loss: 0.068898] [G loss: 3.692736] [Elapsed time: 1534.72s]
# [Epoch 171/200] [D loss: 0.109132] [G loss: 3.204837] [Elapsed time: 1543.74s]
# [Epoch 172/200] [D loss: 0.128587] [G loss: 2.169172] [Elapsed time: 1552.67s]
# [Epoch 173/200] [D loss: 0.175661] [G loss: 1.943366] [Elapsed time: 1561.57s]
# [Epoch 174/200] [D loss: 0.139670] [G loss: 2.705380] [Elapsed time: 1570.49s]
# [Epoch 175/200] [D loss: 0.103767] [G loss: 2.260656] [Elapsed time: 1579.50s]
# [Epoch 176/200] [D loss: 0.103260] [G loss: 2.976569] [Elapsed time: 1588.45s]
# [Epoch 177/200] [D loss: 0.315899] [G loss: 3.342898] [Elapsed time: 1597.37s]
# [Epoch 178/200] [D loss: 0.170191] [G loss: 3.404268] [Elapsed time: 1606.29s]
# [Epoch 179/200] [D loss: 0.105216] [G loss: 2.619538] [Elapsed time: 1615.21s]
# [Epoch 180/200] [D loss: 0.355805] [G loss: 6.826798] [Elapsed time: 1624.14s]
# [Epoch 181/200] [D loss: 0.156369] [G loss: 6.896673] [Elapsed time: 1633.12s]
# [Epoch 182/200] [D loss: 0.146986] [G loss: 2.898189] [Elapsed time: 1642.02s]
# [Epoch 183/200] [D loss: 0.281254] [G loss: 6.495974] [Elapsed time: 1650.96s]
# [Epoch 184/200] [D loss: 0.184373] [G loss: 2.073430] [Elapsed time: 1659.87s]
# [Epoch 185/200] [D loss: 0.139306] [G loss: 4.465373] [Elapsed time: 1668.89s]
# [Epoch 186/200] [D loss: 0.160412] [G loss: 2.132426] [Elapsed time: 1677.85s]
# [Epoch 187/200] [D loss: 0.258381] [G loss: 2.399672] [Elapsed time: 1686.87s]
# [Epoch 188/200] [D loss: 0.153924] [G loss: 3.551443] [Elapsed time: 1695.84s]
# [Epoch 189/200] [D loss: 0.142849] [G loss: 4.228670] [Elapsed time: 1704.78s]
# [Epoch 190/200] [D loss: 0.220259] [G loss: 4.470220] [Elapsed time: 1713.77s]
# [Epoch 191/200] [D loss: 0.108402] [G loss: 3.464035] [Elapsed time: 1722.72s]
# [Epoch 192/200] [D loss: 0.077644] [G loss: 2.432315] [Elapsed time: 1731.69s]
# [Epoch 193/200] [D loss: 0.107456] [G loss: 3.009042] [Elapsed time: 1740.59s]
# [Epoch 194/200] [D loss: 0.175909] [G loss: 2.582804] [Elapsed time: 1749.53s]
# [Epoch 195/200] [D loss: 0.081648] [G loss: 3.058659] [Elapsed time: 1758.46s]
# [Epoch 196/200] [D loss: 0.078730] [G loss: 3.006425] [Elapsed time: 1767.38s]
# [Epoch 197/200] [D loss: 0.064068] [G loss: 3.111226] [Elapsed time: 1776.36s]
# [Epoch 198/200] [D loss: 0.160723] [G loss: 2.543777] [Elapsed time: 1785.34s]
# [Epoch 199/200] [D loss: 0.082356] [G loss: 3.249807] [Elapsed time: 1794.29s]

# %%
from IPython.display import Image

Image('92000.png')
